# %%
# installing yolov8
# %pip install ultralytics

# %%
import torch

# %%
# device setup
device = "cude" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cude'

# %%
# !yolo task=segment mode=train epochs=100 data=/content/drive/MyDrive/Deep_Learning_Projects/Butterfly_segmentation/Butterfly_Segmentation/dataset/dataset.yaml model=yolov8m-seg.pt imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mv best.pt yolov8m-seg-custom.pt

# %%
from ultralytics import YOLO

model = YOLO("yolov8m-seg-custom.pt")

# inferencing with images
model.predict(source='/content/1.png', show=False, save=True, show_labels=False, show_conf=False, conf=0.5,  save_txt=False, save_crop=False, line_thickness=2, boxes=False)

# %%
# inferencing with video
model.predict(source='/content/test_videos/butterfly_video_#03.mp4', show=False, save=True, show_labels=True, show_conf=True, conf=0.5,  save_txt=False, save_crop=False, line_thickness=2, boxes=True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/369) /content/test_videos/butterfly_video_#03.mp4: 384x640 1 butterfly, 31.7ms
# video 1/1 (2/369) /content/test_videos/butterfly_video_#03.mp4: 384x640 1 butterfly, 31.5ms
# video 1/1 (3/369) /content/test_videos/butterfly_video_#03.mp4: 384x640 1 butterfly, 31.8ms
# video 1/1 (4/369) /content/test_videos/butterfly_video_#03.mp4: 384x640 1 butterfly, 27.8ms
# ...

# %%
# inferencing with video
model.predict(source='/content/test_videos/butterfly_video_#02.mp4', show=False, save=True, show_labels=False, show_conf=False, conf=0.5,  save_txt=False, save_crop=False, line_thickness=2, boxes=False)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/388) /content/test_videos/butterfly_video_#02.mp4: 384x640 1 butterfly, 94.6ms
# video 1/1 (2/388) /content/test_videos/butterfly_video_#02.mp4: 384x640 1 butterfly, 31.6ms
# video 1/1 (3/388) /content/test_videos/butterfly_video_#02.mp4: 384x640 1 butterfly, 31.5ms
# video 1/1 (4/388) /content/test_videos/butterfly_video_#02.mp4: 384x640 1 butterfly, 31.6ms
# ...
